# %%
# Mount ADLS Gen2 container to Databricks

configs = {
  "fs.azure.account.auth.type": "OAuth",
  "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
  "fs.azure.account.oauth2.client.id": "077867ea-ba25-4a33-8244-632780d16e76",
  "fs.azure.account.oauth2.client.secret": "IP08Q~j6XqKfMeIrJNNp2ZdJSXp4BGN6eGqmhcm5",
  "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/9a0a69d1-0dfe-44c3-b0b2-8755fb51cc11/oauth2/token"
}

container_name = "modastyle"
storage_account = "modastylelake"
mount_point = "/mnt/modastyle"

dbutils.fs.mount(
  source = f"abfss://{container_name}@{storage_account}.dfs.core.windows.net/",
  mount_point = mount_point,
  extra_configs = configs
)

# %%
dbutils.fs.mounts()

print(dbutils.fs.ls("/mnt/modastyle"))

# %%
folders = ["raw", "bronze", "silver", "gold"]
for f in folders:
    path = f"/mnt/modastyle/{f}"
    dbutils.fs.mkdirs(path)
    print(f"Created: {path}")

# %%
df = spark.range(5)
df.write.format("delta").mode("overwrite").save("/mnt/modastyle/bronze/test_table")
display(dbutils.fs.ls("/mnt/modastyle/bronze"))
